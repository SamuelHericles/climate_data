# %%
#import needed
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_climate = pd.read_csv('data_fortaleza-CE.csv')
data_climate.head()
# Out:
#   codigo_estacao        data  hora  temp_inst  temp_max  temp_min  umid_inst  \
# 0           A305  12/05/2019    13       30.4      30.4      29.0         67
# 1           A305  12/05/2019    11       28.4       NaN       NaN         76
# 2           A305  12/05/2019    14       30.9      31.0      29.6         58
# 3           A305  12/05/2019    12       29.0      29.7      28.3         72
# 4           A305  12/05/2019    15       32.1      32.3      30.9         55
#
#    umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  pto_orvalho_min  \
# 0      73.0      64.0              23.5             24.1             22.2
# 1       NaN       NaN              23.7              NaN              NaN
# 2      67.0      58.0              21.7             23.4             21.7
# 3      76.0      68.0              23.5             24.3             22.8
# 4      60.0      53.0              22.1             23.4             21.2
#
# ...

# %%
data_pto_dew_inst = pd.DataFrame(data_climate[['hora','pto_orvalho_inst']])
data_pto_dew_inst.head()
# Out:
#    hora  pto_orvalho_inst
# 0    13              23.5
# 1    11              23.7
# 2    14              21.7
# 3    12              23.5
# 4    15              22.1

# %%
mean_pto_dew_inst = data_pto_dew_inst.pto_orvalho_inst.mean()
mean_pto_dew_inst
# Out:
# 21.689973753280842

# %%
data_pto_dew_inst = data_pto_dew_inst.fillna({'pto_orvalho_inst':mean_pto_dew_inst})
data_pto_dew_inst.head()
# Out:
#    hora  pto_orvalho_inst
# 0    13              23.5
# 1    11              23.7
# 2    14              21.7
# 3    12              23.5
# 4    15              22.1

# %%
data_pto_dew_inst.pto_orvalho_inst.value_counts()
# Out:
# 22.6    74
# 22.7    64
# 22.1    61
# 22.3    60
# 22.5    60
#         ..
# 17.4     1
# 24.5     1
# 24.6     1
# 16.4     1
# 24.7     1
# Name: pto_orvalho_inst, Length: 80, dtype: int64

# %%
sns.distplot(data_pto_dew_inst.pto_orvalho_inst)

# %%
sns.boxplot(data_pto_dew_inst.pto_orvalho_inst)

# %%
sns.barplot(x='hora',y='pto_orvalho_inst',data=data_pto_dew_inst,palette='GnBu_d')

# %%
x = data_pto_dew_inst.hora
y = data_pto_dew_inst.pto_orvalho_inst
plt.plot(x,y)
plt.xlabel('hora')
plt.ylabel('pto_orvalho_inst')
# Out:
# Text(0, 0.5, 'pto_orvalho_inst')

# %%
plt.scatter(x='hora',y='pto_orvalho_inst',data=data_pto_dew_inst)

# %%
sns.lineplot(x='hora',y='pto_orvalho_inst',data=data_pto_dew_inst)

# %%
'''
                                    EVALUATING MAX DEW
'''
# Out:
# '\n                                    EVALUATING MAX DEW\n'

# %%
data_pto_dew_max = pd.DataFrame(data_climate[['hora','pto_orvalho_max']])
data_pto_dew_max.head()
# Out:
#    hora  pto_orvalho_max
# 0    13             24.1
# 1    11              NaN
# 2    14             23.4
# 3    12             24.3
# 4    15             23.4

# %%
mean_pto_dew_max = data_pto_dew_max.pto_orvalho_max.mean()
mean_pto_dew_max
# Out:
# 22.138235294117646

# %%
data_pto_dew_max = data_pto_dew_max.fillna({'pto_orvalho_max':mean_pto_dew_max})
data_pto_dew_max.head()
# Out:
#    hora  pto_orvalho_max
# 0    13        24.100000
# 1    11        22.138235
# 2    14        23.400000
# 3    12        24.300000
# 4    15        23.400000

# %%
sns.distplot(data_pto_dew_max.pto_orvalho_max)

# %%
sns.boxplot(data_pto_dew_max.pto_orvalho_max)

# %%
sns.barplot(x='hora',y='pto_orvalho_max',data=data_pto_dew_max,palette='GnBu_d')

# %%
x = data_pto_dew_max.hora
y = data_pto_dew_max.pto_orvalho_max
plt.plot(x,y)
plt.xlabel('Hours')
plt.ylabel('pto_orvalho_max')
# Out:
# Text(0, 0.5, 'pto_orvalho_max')

# %%
plt.scatter(x='hora',y='pto_orvalho_max',data=data_pto_dew_max)

# %%
sns.lineplot(x='hora',y='pto_orvalho_max',data=data_pto_dew_max)

# %%
'''
                                            EVALUATING MIN DEW
'''
