# %% [markdown]
# # In this file we to see the correlations into table's parameters

# %%
import pandas as pd
data_climate = pd.read_csv('data_fortaleza-CE.csv')
data_climate.head()
# Out:
#   codigo_estacao        data  hora  temp_inst  temp_max  temp_min  umid_inst  \
# 0           A305  12/05/2019    13       30.4      30.4      29.0         67
# 1           A305  12/05/2019    11       28.4       NaN       NaN         76
# 2           A305  12/05/2019    14       30.9      31.0      29.6         58
# 3           A305  12/05/2019    12       29.0      29.7      28.3         72
# 4           A305  12/05/2019    15       32.1      32.3      30.9         55
#
#    umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  pto_orvalho_min  \
# 0      73.0      64.0              23.5             24.1             22.2
# 1       NaN       NaN              23.7              NaN              NaN
# 2      67.0      58.0              21.7             23.4             21.7
# 3      76.0      68.0              23.5             24.3             22.8
# 4      60.0      53.0              22.1             23.4             21.2
#
# ...

# %%
data_climate.corr()
# Out:
#                       hora  temp_inst  temp_max  temp_min  umid_inst  \
# hora              1.000000   0.516744  0.556031  0.528891  -0.497390
# temp_inst         0.516744   1.000000  0.979192  0.959703  -0.890714
# temp_max          0.556031   0.979192  1.000000  0.965113  -0.878483
# temp_min          0.528891   0.959703  0.965113  1.000000  -0.855495
# umid_inst        -0.497390  -0.890714 -0.878483 -0.855495   1.000000
# umid_max         -0.511646  -0.849706 -0.858278 -0.877799   0.963713
# umid_min         -0.551030  -0.883958 -0.903242 -0.871138   0.980286
# pto_orvalho_inst -0.182804  -0.253629 -0.257195 -0.244174   0.656368
# pto_orvalho_max  -0.131461  -0.086430 -0.090924 -0.109771   0.498717
# pto_orvalho_min  -0.284897  -0.381593 -0.390166 -0.362512   0.733356
# pressao          -0.268614  -0.182282 -0.220784 -0.267025  -0.007512
# pressao_max      -0.269042  -0.104594 -0.145822 -0.195194  -0.077412
# pressao_min      -0.293610  -0.132830 -0.172307 -0.217279  -0.055809
# ...

# %%
data_climate.corr(method='spearman')
# Out:
#                       hora  temp_inst  temp_max  temp_min  umid_inst  \
# hora              1.000000   0.534841  0.568306  0.540181  -0.515648
# temp_inst         0.534841   1.000000  0.979755  0.958375  -0.882049
# temp_max          0.568306   0.979755  1.000000  0.962295  -0.870017
# temp_min          0.540181   0.958375  0.962295  1.000000  -0.846276
# umid_inst        -0.515648  -0.882049 -0.870017 -0.846276   1.000000
# umid_max         -0.522776  -0.835771 -0.843328 -0.866989   0.958700
# umid_min         -0.565971  -0.875668 -0.894448 -0.859888   0.979726
# pto_orvalho_inst -0.187014  -0.196912 -0.204915 -0.195527   0.600604
# pto_orvalho_max  -0.144397  -0.057009 -0.062651 -0.077280   0.462967
# pto_orvalho_min  -0.291080  -0.311420 -0.324323 -0.297107   0.675589
# pressao          -0.265500  -0.164530 -0.199984 -0.240325  -0.023863
# pressao_max      -0.264870  -0.095826 -0.131645 -0.175815  -0.084422
# pressao_min      -0.292065  -0.123963 -0.159688 -0.197577  -0.063528
# ...

# %%
data_climate.corr().temp_max
# Out:
# hora                0.556031
# temp_inst           0.979192
# temp_max            1.000000
# temp_min            0.965113
# umid_inst          -0.878483
# umid_max           -0.858278
# umid_min           -0.903242
# pto_orvalho_inst   -0.257195
# pto_orvalho_max    -0.090924
# pto_orvalho_min    -0.390166
# pressao            -0.220784
# pressao_max        -0.145822
# pressao_min        -0.172307
# vento_direcao       0.711980
# vento_vel          -0.556712
#  vento_rajada       0.693179
# radiacao            0.844036
# precipitacao       -0.165757
# Name: temp_max, dtype: float64

# %%
data_climate.corr()["vento_vel"]
# Out:
# hora               -0.418446
# temp_inst          -0.533809
# temp_max           -0.556712
# temp_min           -0.605640
# umid_inst           0.473500
# umid_max            0.524727
# umid_min            0.510145
# pto_orvalho_inst    0.070497
# pto_orvalho_max     0.036462
# pto_orvalho_min     0.138531
# pressao             0.136827
# pressao_max         0.120547
# pressao_min         0.130260
# vento_direcao      -0.462748
# vento_vel           1.000000
#  vento_rajada      -0.502231
# radiacao           -0.271172
# precipitacao        0.049285
# Name: vento_vel, dtype: float64

# %%
data_climate.corr()["vento_direcao"]
# Out:
# hora                0.463580
# temp_inst           0.714989
# temp_max            0.711980
# temp_min            0.675270
# umid_inst          -0.801431
# umid_max           -0.756952
# umid_min           -0.788170
# pto_orvalho_inst   -0.511781
# pto_orvalho_max    -0.363617
# pto_orvalho_min    -0.582385
# pressao             0.020544
# pressao_max         0.075045
# pressao_min         0.050808
# vento_direcao       1.000000
# vento_vel          -0.462748
#  vento_rajada       0.896413
# radiacao            0.748001
# precipitacao       -0.069705
# Name: vento_direcao, dtype: float64

# %%
data_climate.corr(method='spearman')["vento_direcao"]
# Out:
# hora                0.466679
# temp_inst           0.725972
# temp_max            0.714145
# temp_min            0.674258
# umid_inst          -0.809477
# umid_max           -0.751868
# umid_min           -0.791801
# pto_orvalho_inst   -0.498533
# pto_orvalho_max    -0.356971
# pto_orvalho_min    -0.569725
# pressao             0.027306
# pressao_max         0.080398
# pressao_min         0.053073
# vento_direcao       1.000000
# vento_vel          -0.448311
#  vento_rajada       0.900978
# radiacao            0.708003
# precipitacao       -0.144132
# Name: vento_direcao, dtype: float64
