# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
import math
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing

#to set dimensions of the figures
plt.rcParams['figure.figsize'] = (15,7)

x_all_parameters = pd.read_csv('x_all_parameters.csv')
y_all_parameters = pd.read_csv('y_all_parameters.csv')

x = x_all_parameters.as_matrix()
y = y_all_parameters.as_matrix()

x = np.delete(x,0,1)
y = np.delete(y,0,1)

mm_scaler = preprocessing.MinMaxScaler()
x_norm = mm_scaler.fit_transform(x)
y_norm = mm_scaler.fit_transform(y)

#Creating a dataset for store rmse and r2 results
#values_all_parameters = pd.DataFrame(columns=['i','j','rmse','r2'])
#values_all_parameters_matrix = pd.DataFrame(columns=['i','j','rmse','r2'])
values_all_parameters_norm = pd.DataFrame(columns=['i','j','rmse','r2'])
# Out:
# c:\users\pet\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# c:\users\pet\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
def test_mlp(x,y,i,j):
    warnings.filterwarnings('ignore')

    train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.2)

    MLP_reg = MLPRegressor(hidden_layer_sizes = (i*30,j*30), activation='tanh',
                      verbose=False, warm_start=True,
                      max_iter = 300)

    MLP_reg.fit(train_x,train_y)#Kernel default : RBF 
    predicts = MLP_reg.predict(test_x)

    rmse = math.sqrt(mean_squared_error(test_y,predicts))
    score_r2 = r2_score(test_y,predicts)

    return i*30,j*30,rmse,score_r2

def run_test_mlp(interval,dataset,x,y):
    #To mesure time processing
    import time 
    inicio = time.time()
    a = 0
    #Begin cycle for
    for i in range(1,interval+1):
        for j in range(1,interval+1): 
            dataset.loc[a] = test_mlp(x,y,i,j)
            print("{}->{}".format(a,dataset.r2[a]))
            a = a + 1
    #End cycle for
    
    fim = time.time()
    print(fim-inicio)
    return dataset

# %%
#values_all_parameters = run_test_mlp(1,values_all_parameters,x_all_parameters,y_all_parameters)

# %%
#values_all_parameters_matrix = run_test_mlp(1,values_all_parameters_matrix,x,y)

# %%
#values_all_parameters.to_csv('/home/archie/Arquivos/climate/Datasets/values_all_parameters.csv')
#values_all_parameters = pd.read_csv('/home/archie/Arquivos/climate/Datasets/values_all_parameters.csv')

#values_all_parameters_matrix.to_csv('/home/archie/Arquivos/climate/Datasets/values_all_parameters_matrix.csv')
#values_all_parameters_matrix = pd.read_csv('/home/archie/Arquivos/climate/Datasets/values_all_parameters_matrix.csv')

# %%
#values_all_parameters.head()

# %%
#values_all_parameters_matrix.head()

# %%
values_all_parameters_norm = run_test_mlp(20,values_all_parameters_norm,x_norm,y_norm)
# Out:
# 0->-0.07356112248231184
# 1->0.011392433097736077
# 2->-0.004968243328417499
# 3->0.007197471434434721
# 4->0.0032911808650279983
# 5->-0.08881939477316836
# 6->-0.2328672384142847
# 7->-0.03953375396068659
# 8->-0.09468622668429427
# 9->-0.039332629270257824
# 10->-0.0909796017761324
# 11->-0.049200911944998316
# 12->0.04975017255584835
# 13->0.010842874696683324
# 14->-0.03665806974477004
# 15->-0.09061367647693008
# 16->-0.0927819373450518
# 17->0.001962835376076666
# 18->-0.3840514561809496
# 19->0.0026941382536977976
# 20->0.016657266949163807
# 21->-0.022248854868363255
# 22->-0.12318556187117857
# 23->-0.008392895117552257
# 24->-0.02282754354586447
# 25->-0.01722689983170045
# 26->0.01411657054137272
# 27->-0.059677470891731366
# 28->-0.2324602044347055
# 29->-0.01699445798827348
# 30->-0.020930811314340714
# 31->-0.026439944172420127
# 32->-0.05719235716651472
# 33->-0.0019709586201526186
# 34->-0.11145827008563858
# 35->0.006581992748610266
# 36->0.015516880648968279
# 37->-0.07328386637977702
# 38->-0.018829331636319058
# 39->-0.09133651517588581
# 40->-0.1004156736233095
# 41->-0.05459370042490863
# 42->-0.09740606375988214
# 43->0.033619851109614185
# 44->-0.07317991814020286
# 45->-0.01808867136453496
# 46->0.030561585267451008
# 47->-0.0034742635424112045
# 48->-0.01331173234663141
# 49->0.01409248443646638
# 50->0.025642288201764618
# 51->-0.057063704886030964
# 52->-0.1507083918232317
# 53->0.0031926719007809856
# 54->-0.0529105968095287
# 55->-0.06851593881918205
# 56->-0.12195709906101149
# 57->-0.011709955269867178
# 58->-0.06829770254225664
# 59->-0.25965938130562116
# 60->-0.11138720213242359
# 61->0.002401021925098612
# 62->0.04664163527916698
# 63->-0.25148262275087174
# 64->-0.013105826023834366
# 65->-0.15705486583534878
# 66->-0.0022943911365529424
# 67->-0.07470993772720913
# 68->-0.17149214820705172
# 69->-0.018753670826900493
# 70->-0.11651918647225346
# 71->-0.2750072059093527
# 72->0.02489833203499403
# 73->-0.07691000798157832
# 74->-0.17920050659948417
# 75->-0.023102740435502644
# 76->-0.7343180367911681
# 77->-0.07336380737794057
# 78->-0.05360868301425792
# 79->0.011793743108019727
# 80->-0.17477408736638878
# 81->-0.012792316908701862
# 82->-0.09210362152255946
# 83->-0.2848325021166689
# 84->-0.418220139004549
# 85->0.02444218223654049
# 86->-0.035508735827780136
# 87->-0.2465111822357573
# 88->-0.11531612875815589
# 89->-0.020113738019154725
# 90->0.024091260644689916
# 91->-0.13427577653832357
# 92->-0.06302863915759938
# 93->-0.01313908225049687
# 94->-0.44924379357130073
# 95->-0.22916538119053698
# 96->-0.036961203698272715
# 97->-0.10747522328609493
# 98->-0.0271731972654099
# 99->-0.11409562006463636
# 100->-0.07635660227497998
# 101->-0.2550401192932379
# 102->-0.04454400081748
# 103->-0.047247155303648425
# 104->-0.05124547693125048
# 105->-0.12625554490008772
# 106->-0.03214712177436341
# 107->-0.024995163086323435
# 108->-0.09766210229081551
# 109->-0.06483363051402935
# 110->0.04000901440734772
# 111->-0.034221857390295485
# 112->-0.025902858772367088
# 113->-0.08351579957409583
# 114->-0.14951178765602613
# 115->-0.006876823886196259
# 116->-0.0460017355366058
# 117->-0.07751210435030997
# 118->-0.08183247673648553
# 119->-0.18146814970655445
# 120->0.0032196552977824533
# 121->0.03545908034416956
# 122->-0.1678528508721422
# 123->0.02187616353238042
# 124->0.02111509900242481
# 125->0.03267605211212432
# 126->-0.02296292981560044
# 127->-0.09259495894925052
# 128->-0.0874827557490474
# 129->-0.0032472244194057254
# 130->-0.19145296220405505
# 131->-0.09454180153282299
# 132->-0.10874174283910909
# 133->-0.07901829992536391
# 134->-0.05782415627051907
# 135->-0.49731815631820386
# 136->-0.13781767659813848
# 137->-0.008682924053430074
# 138->0.024205283147200052
# 139->0.0618526673876465
# 140->-0.048221229437422464
# 141->-0.21730322915501765
# 142->-0.15310141501221008
# 143->-0.0536186363167197
# 144->-0.11605904031118075
# 145->-0.2395930545218674
# 146->-0.2995127330552465
# 147->-0.034705461831225026
# 148->0.004313339229381596
# 149->-0.051292197943216156
# 150->-0.08268164568596137
# 151->-0.11824694069707742
# 152->-0.009073872818272877
# 153->-0.13402276198816465
# 154->-0.006477507979611774
# 155->-0.00047582700559334334
# 156->-0.12559963005100516
# 157->-0.19795177650954088
# 158->-0.34954513675692667
# 159->-0.03638093602331849
# 160->-0.04721564184915805
# 161->0.0006661850461073815
# 162->-0.02947584634625211
# 163->-0.18189677324800946
# 164->-0.03201813670864251
# 165->-0.20107138778025657
# 166->0.02573274457137309
# 167->-0.024301713976543127
# 168->-0.514733537460512
# 169->-0.23699039720317794
# 170->-0.15506867163397975
# 171->0.0407689187679402
# 172->-0.10624096225338087
# 173->-0.10890456074980248
# 174->-0.05666140534438391
# 175->0.007240626787158422
# 176->-0.03180113781969163
# 177->-0.2966648848175295
# 178->-0.13419089112407723
# 179->-0.3473973706677558
# 180->-0.09743116715901734
# 181->-0.04449118120218354
# 182->-0.04577973004872149
# 183->-0.017827559631027334
# 184->-0.06802229394954362
# 185->-0.1327408617301613
# 186->0.027190501965984493
# 187->-0.2536907491969227
# 188->-0.036817160980683994
# 189->-0.0542550246431166
# 190->-0.21640295288411537
# 191->-0.01556189555557852
# 192->-0.07611041277768837
# 193->-0.3892229299317702
# 194->-0.08792578938879703
# 195->-0.4751021178152841
# 196->-0.03683252713049012
# 197->-0.0034464804814557937
# 198->-0.15073748717491497
# 199->-0.23945102821545894
# 200->-0.109618357616593
# 201->-0.07516314322984052
# 202->0.03508522508477163
# 203->-0.019648837489439908
# 204->-0.24825095275767484
# 205->-0.010362496454323189
# 206->-0.1427291764201346
# 207->-0.18987963879866943
# 208->-0.05082441429038531
# 209->-0.2980842876873233
# 210->-0.1400600098488607
# 211->-0.17142206833354678
# 212->-0.20799372024927054
# 213->-0.038219294934407344
# 214->-0.008496757830162904
# 215->-0.7486328742885084
# 216->-0.020605478331309435
# 217->-0.0028916593729559903
# 218->-0.043584233841847064
# 219->0.01096694311579427
# 220->-0.08801884949015437
# 221->-0.03299035995295241
# 222->-0.3770647222890091
# 223->-0.0011240307094892987
# 224->0.0007519359127078351
# 225->-0.05686765885730316
# 226->-0.04020273200149971
# 227->-0.3847104711455731
# 228->-0.027052831889780027
# 229->-0.11611874747706086
# 230->-0.08075564978742178
# 231->-0.22857855138909877
# 232->-0.4614998892327966
# 233->-0.09475651954831554
# 234->0.027736810957713298
# 235->-0.20745874649816676
# 236->-0.09896322696420623
# 237->-0.100874788560539
# 238->-0.1841572594776082
# 239->-0.1504712900720091
# 240->-0.13891668032220106
# 241->-0.01932062624964126
# 242->-0.03792257899087925
# 243->-0.08342460187221756
# 244->-0.008407343314058568
# 245->-0.12245097108908243
# 246->-0.14586556320059474
# 247->-0.06359815259688184
# 248->-0.08329002166852817
# 249->-0.08049115132696527
# 250->0.02741215139474462
# 251->-0.5707853948697792
# 252->-0.00538305839370401
# 253->-0.07707369736370162
# 254->-0.33349131939126275
# 255->-0.11577452928440302
# 256->-0.027173705884860455
# 257->-0.20383928846370436
# 258->-0.20677210629754916
# 259->-0.08298839927640955
# 260->-0.020161829050074243
# 261->-0.022764125958355086
# 262->0.025531325089412027
# 263->-0.05125308134942275
# 264->-0.157121719228821
# 265->-0.12453123435793056
# 266->-0.17739718291374484
# 267->-0.05365020060454562
# 268->-0.11503965798807014
# 269->-0.1166301777544132
# 270->0.010917674457817772
# 271->-0.1279188009023693
# 272->-0.0466683736998581
# 273->-0.12430847592415084
# 274->-0.22913177015436625
# 275->-0.02907191509657836
# 276->-0.1332721684573055
# 277->-0.06315203121236901
# 278->0.06859423806618148
# 279->-0.5232991524055992
# 280->-0.11918020717534894
# 281->-0.15438197192651715
# 282->0.03397984618959782
# 283->0.01063437901140274
# 284->0.0373285233287427
# 285->-0.1754634596893716
# 286->-0.009835967457908712
# 287->-0.008143282101083171
# 288->-0.04648555035428936
# 289->-0.0046357646645360795
# 290->0.03457498400311543
# 291->0.02879044440332179
# 292->-0.04482136898955891
# 293->-0.0748432179564098
# 294->-0.020289692287623007
# 295->0.016135399878770884
# 296->-0.055886059407608935
# 297->-0.07590295159194582
# 298->-0.11147780897992954
# 299->-0.02316008590207086
# 300->-0.0028874635102407176
# 301->-0.4731237137289612
# 302->-0.044569304197333626
# 303->-0.04125682110751727
# 304->-0.055577387178704196
# 305->0.04332443492995197
# 306->-0.3113981245702211
# 307->-0.5917274356639268
# 308->-0.08804173236836599
# 309->-0.15894929691186332
# 310->-0.00029422410028523416
# 311->-0.4481113700975361
# 312->-0.03527630661562764
# 313->-0.13401386897096756
# 314->-0.011974185578516927
# 315->-0.07804808071342806
# 316->-0.055469097779760945
# 317->-0.11662085397414157
# 318->-0.008951020064952964
# 319->-0.031736309091153325
# 320->-0.012723884325911428
# 321->-0.01635494684517247
# 322->-0.4561450827440052
# 323->-0.07149955106409922
# 324->-0.14147645357376448
# 325->-0.14338822829958975
# 326->-0.017496894965165932
# 327->-0.052324995724865486
# 328->0.006761593022485801
# 329->-0.03929747591742605
# 330->0.0019809713169708365
# 331->-0.2482156081650564
# 332->-0.04278742430895899
# 333->-0.029192264515843114
# 334->-0.1637277169439746
# 335->-0.030926904350921047
# 336->0.032949088107000146
# 337->-0.009180294846014903
# 338->-0.006709951812030379
# 339->0.01223862431989342
# 340->-0.1581964355241876
# 341->-0.40658697600758553
# 342->-0.03465869454710324
# 343->-0.039173468599988714
# 344->-0.18043222984579965
# 345->-0.5012829256111881
# 346->-0.024928741005949995
# 347->-0.03070356522159856
# 348->-0.09910828200449662
# 349->-0.04151435350319832
# 350->-0.10645274847825426
# 351->0.014115928441861159
# 352->-0.0969969992723625
# 353->-0.0815353602073241
# 354->-0.1386827886044193
# 355->-0.2964306843876525
# 356->-0.10026307796730305
# 357->-0.003694223807239272
# 358->-0.0611891506914084
# 359->-0.08524914842503617
# 360->0.005559275081105541
# 361->-0.00809924444006227
# 362->-0.6542769987690544
# 363->-0.23090842117257426
# 364->-0.18144509752796822
# 365->-0.13485043542505215
# 366->-0.14300210025393612
# 367->-0.14173556684787436
# 368->-0.10635381375710717
# 369->-0.07700809321332103
# 370->-0.11488680997730039
# 371->-0.011833654909134239
# 372->-0.0347974738451029
# 373->0.006876280637303167
# 374->-0.2113059085390414
# 375->-0.06923591719183975
# 376->-0.08090628780484144
# 377->-0.1099807114856961
# 378->-0.08604514951512798
# 379->-0.06865661414945912
# 380->-0.1323751222253291
# 381->-0.10665470134074195
# 382->-0.05504387381195608
# 383->-0.017555301732109285
# 384->-0.052288276640706455
# 385->-0.19346749760409754
# 386->-0.1285531252643859
# 387->-0.14891665443866398
# 388->0.003594985471558676
# 389->-0.07272408620772852
# 390->-0.023144250966798285
# 391->-0.15303253304471798
# 392->-0.25887486137861515
# 393->0.01867993033624027
# 394->0.017258699410855782
# 395->-0.0059181152860892094
# 396->-0.44637675307035374
# 397->-0.20938594050571457
# 398->0.011515031011219645
# 399->-0.21232285330022216
# 1495.9528937339783

# %%
values_all_parameters_norm.to_csv('values_all_parameters_norm.csv')
values_all_parameters_norm = pd.read_csv('values_all_parameters_norm.csv')

# %%
values_all_parameters_norm.describe()
# Out:
#        Unnamed: 0           i           j        rmse          r2
# count  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   199.500000  315.000000  315.000000    0.193188   -0.098326
# std    115.614301  173.205081  173.205081    0.011519    0.127124
# min      0.000000   30.000000   30.000000    0.168587   -0.748633
# 25%     99.750000  172.500000  172.500000    0.184963   -0.134419
# 50%    199.500000  315.000000  315.000000    0.191441   -0.063375
# 75%    299.250000  457.500000  457.500000    0.198637   -0.016157
# max    399.000000  600.000000  600.000000    0.234228    0.068594
