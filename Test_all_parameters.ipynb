# %%
import pandas as pd
data_climate = pd.read_csv('data_fortaleza-CE.csv')
data_climate.head()
# Out:
#   codigo_estacao        data  hora  temp_inst  temp_max  temp_min  umid_inst  \
# 0           A305  12/05/2019    13       30.4      30.4      29.0         67
# 1           A305  12/05/2019    11       28.4       NaN       NaN         76
# 2           A305  12/05/2019    14       30.9      31.0      29.6         58
# 3           A305  12/05/2019    12       29.0      29.7      28.3         72
# 4           A305  12/05/2019    15       32.1      32.3      30.9         55
#
#    umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  pto_orvalho_min  \
# 0      73.0      64.0              23.5             24.1             22.2
# 1       NaN       NaN              23.7              NaN              NaN
# 2      67.0      58.0              21.7             23.4             21.7
# 3      76.0      68.0              23.5             24.3             22.8
# 4      60.0      53.0              22.1             23.4             21.2
#
# ...

# %%
data_climate.corr()
# Out:
#                       hora  temp_inst  temp_max  temp_min  umid_inst  \
# hora              1.000000   0.516744  0.556031  0.528891  -0.497390
# temp_inst         0.516744   1.000000  0.979192  0.959703  -0.890714
# temp_max          0.556031   0.979192  1.000000  0.965113  -0.878483
# temp_min          0.528891   0.959703  0.965113  1.000000  -0.855495
# umid_inst        -0.497390  -0.890714 -0.878483 -0.855495   1.000000
# umid_max         -0.511646  -0.849706 -0.858278 -0.877799   0.963713
# umid_min         -0.551030  -0.883958 -0.903242 -0.871138   0.980286
# pto_orvalho_inst -0.182804  -0.253629 -0.257195 -0.244174   0.656368
# pto_orvalho_max  -0.131461  -0.086430 -0.090924 -0.109771   0.498717
# pto_orvalho_min  -0.284897  -0.381593 -0.390166 -0.362512   0.733356
# pressao          -0.268614  -0.182282 -0.220784 -0.267025  -0.007512
# pressao_max      -0.269042  -0.104594 -0.145822 -0.195194  -0.077412
# pressao_min      -0.293610  -0.132830 -0.172307 -0.217279  -0.055809
# ...

# %%
import seaborn as sns
sns.pairplot(data_climate)
